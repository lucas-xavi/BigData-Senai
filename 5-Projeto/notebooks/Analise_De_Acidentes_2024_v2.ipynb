# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Caminho para o arquivo da análise
path = '/content/acidentes2024_todas_causas_tipos_vs2.csv'

# Criado a função createDataFrame para usar o DataFrame
def createDataFrame() -> pd.DataFrame:
    data = pd.read_csv(path, delimiter=';', low_memory=False, encoding='UTF-8', dtype=str)
    df = pd.DataFrame(data)

    #Removi as colunas latitude, longitude, regional, delegacia, uop, pois não considero importante para minha análise.
    df.drop(columns=['latitude','longitude','regional','delegacia','uop'],inplace=True)

    return df

# %%
# Armazenando a função createDataFrame na váriavel df.
df = createDataFrame()

# %%
#df.info()

# %%
# Visualização dos 5 primeiros registros.
df.head()
# Out:
#        id    pesid data_inversa     dia_semana   horario  uf   br     km  \
# 0  571772  1268971   01/01/2024  segunda-feira  00:05:00  RJ  101  272,5
# 1  571774  1268985   01/01/2024  segunda-feira  00:05:00  GO  153  424,6
# 2  571774  1268985   01/01/2024  segunda-feira  00:05:00  GO  153  424,6
# 3  571777  1269020   01/01/2024  segunda-feira  01:45:00  ES  101  264,1
# 4  571778  1269028   01/01/2024  segunda-feira  00:45:00  SC  101    110
#
#   municipio causa_principal  ...                     marca  \
# 0    TANGUA             Sim  ...          HONDA/CG 160 FAN
# 1  ANAPOLIS             Não  ...          VW/GOL 1.6 POWER
# 2  ANAPOLIS             Sim  ...          VW/GOL 1.6 POWER
# 3     SERRA             Sim  ...            VW/SAVEIRO 1.6
# 4     PENHA             Não  ...  I/SSANGYONG ACTYON A23 4
#
#   ano_fabricacao_veiculo tipo_envolvido estado_fisico idade       sexo ilesos  \
# 0                   2023       Condutor         Óbito    26  Masculino      0
# 1                   2009       Condutor         Ileso    34   Feminino      1
# 2                   2009       Condutor         Ileso    34   Feminino      1
# 3                   2009       Condutor         Ileso    55  Masculino      1
# 4                   2011       Condutor         Ileso    53  Masculino      1
#
#   feridos_leves feridos_graves mortos
# 0             0              0      1
# 1             0              0      0
# 2             0              0      0
# 3             0              0      0
# 4             0              0      0
#
# [5 rows x 32 columns]

# %%
# Pesquisando por tipo_envolvido, para se ter uma visão mais amplas sobre os dados nullos.
df[df['tipo_envolvido'].isna()].sample(5)
# Out:
#             id pesid data_inversa    dia_semana   horario  uf   br    km  \
# 277714  610563   NaN   28/06/2024   sexta-feira  08:50:00  MS  163  25,6
# 299029  613387   NaN   10/07/2024  quarta-feira  04:30:00  GO   60   404
# 35273   576665   NaN   23/01/2024   terça-feira  07:40:00  RS  392   204
# 178259  597036   NaN   28/04/2024       domingo  19:15:00  BA  367    28
# 49004   578709   NaN   03/02/2024        sábado  06:30:00  PA  163   591
#
#                    municipio causa_principal  ...                 marca  \
# 277714            MUNDO NOVO             Não  ...     SR/NOMA SR3E27 CG
# 299029             RIO VERDE             Sim  ...       SR/RANDON SR CA
# 35273   SANTANA DA BOA VISTA             Sim  ...       SR/GUERRA AG GR
# 178259          PORTO SEGURO             Sim  ...  SR/LIBRELATO SRCT 2E
# 49004                TRAIRAO             Não  ...       SR/RANDON SR TQ
#
#        ano_fabricacao_veiculo tipo_envolvido estado_fisico idade sexo ilesos  \
# 277714                   2020            NaN           NaN   NaN  NaN    NaN
# 299029                   2002            NaN           NaN   NaN  NaN    NaN
# 35273                    2010            NaN           NaN   NaN  NaN    NaN
# 178259                   2005            NaN           NaN   NaN  NaN    NaN
# 49004                    2014            NaN           NaN   NaN  NaN    NaN
#
#        feridos_leves feridos_graves mortos
# 277714           NaN            NaN    NaN
# 299029           NaN            NaN    NaN
# 35273            NaN            NaN    NaN
# 178259           NaN            NaN    NaN
# 49004            NaN            NaN    NaN
#
# [5 rows x 32 columns]

# %%
# Filtrei por alguns Ids, pois a cada vez que verificava, tinha-se muitos ids com multiplos registros.
df[df['id']== '661121']
# Out:
#             id    pesid data_inversa dia_semana   horario  uf   br     km  \
# 601564  661121      NaN   21/12/2024     sábado  03:45:00  MG  116  286,5
# 601565  661121      NaN   21/12/2024     sábado  03:45:00  MG  116  286,5
# 601566  661121  1490712   21/12/2024     sábado  03:45:00  MG  116  286,5
# 601567  661121  1490711   21/12/2024     sábado  03:45:00  MG  116  286,5
# 601568  661121  1490673   21/12/2024     sábado  03:45:00  MG  116  286,5
# ...        ...      ...          ...        ...       ...  ..  ...    ...
# 603099  661121  1490669   21/12/2024     sábado  03:45:00  MG  116  286,5
# 603100  661121  1490668   21/12/2024     sábado  03:45:00  MG  116  286,5
# 603101  661121  1490667   21/12/2024     sábado  03:45:00  MG  116  286,5
# 603102  661121  1490666   21/12/2024     sábado  03:45:00  MG  116  286,5
# 603103  661121  1490660   21/12/2024     sábado  03:45:00  MG  116  286,5
#
#             municipio causa_principal  ...                   marca  \
# 601564  TEOFILO OTONI             Não  ...         SR/RANDON SR CA
# 601565  TEOFILO OTONI             Não  ...         SR/RANDON SR CA
# 601566  TEOFILO OTONI             Não  ...        GM/CHEVROLET D20
# 601567  TEOFILO OTONI             Não  ...        GM/CHEVROLET D20
# 601568  TEOFILO OTONI             Não  ...        GM/CHEVROLET D20
# ...               ...             ...  ...                     ...
# 603099  TEOFILO OTONI             Sim  ...  MBENZ/MPOLO PARADISO R
# 603100  TEOFILO OTONI             Sim  ...  MBENZ/MPOLO PARADISO R
# 603101  TEOFILO OTONI             Sim  ...  MBENZ/MPOLO PARADISO R
# 603102  TEOFILO OTONI             Sim  ...  MBENZ/MPOLO PARADISO R
# 603103  TEOFILO OTONI             Sim  ...  MBENZ/MPOLO PARADISO R
#
#        ano_fabricacao_veiculo tipo_envolvido  estado_fisico idade       sexo  \
# 601564                   2003            NaN            NaN   NaN        NaN
# 601565                   2003            NaN            NaN   NaN        NaN
# 601566                   1986     Passageiro   Lesões Leves    21  Masculino
# 601567                   1986     Passageiro   Lesões Leves    29  Masculino
# 601568                   1986       Condutor          Ileso    71  Masculino
# ...                       ...            ...            ...   ...        ...
# 603099                   2010     Passageiro  Lesões Graves    13   Feminino
# 603100                   2010     Passageiro  Lesões Graves    46  Masculino
# 603101                   2010     Passageiro   Lesões Leves     8  Masculino
# 603102                   2010     Passageiro  Lesões Graves    39   Feminino
# 603103                   2010       Condutor          Óbito    38  Masculino
#
#        ilesos feridos_leves feridos_graves mortos
# 601564    NaN           NaN            NaN    NaN
# 601565    NaN           NaN            NaN    NaN
# 601566      0             1              0      0
# 601567      0             1              0      0
# 601568      1             0              0      0
# ...       ...           ...            ...    ...
# 603099      0             0              1      0
# 603100      0             0              1      0
# 603101      0             1              0      0
# 603102      0             0              1      0
# 603103      0             0              0      1
#
# [1540 rows x 32 columns]

# %%
# Selecionei a coluna tipo_envolvido, para saber os valores que nela continha e qual a relação com o tipo_veiculo, após a análise superficial acima.
df['tipo_envolvido'].unique()
# Out:
# array(['Condutor', 'Passageiro', 'Testemunha', 'Pedestre', nan,
#        'Cavaleiro'], dtype=object)

# %%
# Tive uma dúvida em relação a tipo_envolvido e tipo_veiculo = Semireboque, então usei os códigos abaixos para saber se todo tipo_veiculo = Semireboque tinha o valor NaN.
df[df['tipo_veiculo'] == 'Semireboque']['tipo_envolvido'].isna().all()
# Out:
# np.False_

# %%
# Mostra quantos registros em cada coluna, tem o valor Null
df.isnull().sum()
# Out:
# id                             0
# pesid                      57641
# data_inversa                   0
# dia_semana                     0
# horario                        0
# uf                             0
# br                          1348
# km                          1348
# municipio                      0
# causa_principal                0
# causa_acidente                 0
# ordem_tipo_acidente            0
# tipo_acidente                  0
# classificacao_acidente         3
# fase_dia                       0
# sentido_via                    0
# condicao_metereologica         0
# tipo_pista                     0
# tracado_via                    0
# uso_solo                       0
# id_veiculo                 19572
# tipo_veiculo               19572
# marca                          0
# ano_fabricacao_veiculo     19572
# tipo_envolvido             57641
# estado_fisico              57641
# idade                     109408
# sexo                       57641
# ilesos                     57641
# feridos_leves              57641
# feridos_graves             57641
# mortos                     57641
# dtype: int64

# %%
# Média em porcentagem, para saber quantos valores são nullos
df.isnull().mean() * 100
# Out:
# id                         0.000000
# pesid                      9.555631
# data_inversa               0.000000
# dia_semana                 0.000000
# horario                    0.000000
# uf                         0.000000
# br                         0.223469
# km                         0.223469
# municipio                  0.000000
# causa_principal            0.000000
# causa_acidente             0.000000
# ordem_tipo_acidente        0.000000
# tipo_acidente              0.000000
# classificacao_acidente     0.000497
# fase_dia                   0.000000
# sentido_via                0.000000
# condicao_metereologica     0.000000
# tipo_pista                 0.000000
# tracado_via                0.000000
# uso_solo                   0.000000
# id_veiculo                 3.244614
# tipo_veiculo               3.244614
# marca                      0.000000
# ano_fabricacao_veiculo     3.244614
# tipo_envolvido             9.555631
# estado_fisico              9.555631
# idade                     18.137480
# sexo                       9.555631
# ilesos                     9.555631
# feridos_leves              9.555631
# feridos_graves             9.555631
# mortos                     9.555631
# dtype: float64

# %% [markdown]
# Começando a tratar alguns valores null

# %%
# Verificação da coluna KM, pois mesmo com análise interior, não fazia sentido alguns dados nesse arquivo, como KM = 424,6
df[['km']]
df['km'].unique()
# Ao verificar e pesquisar um pouco, descobri que a coluna KM se trata do kilometro e não da velocidade ao qual o(s) condutor(es) estavam.
# Out:
# array(['272,5', '424,6', '264,1', ..., '590,3', '798,8', '643,3'],
#       dtype=object)

# %%
# Média de acidentes por estado (com todos os dados)
media_completa = df.groupby('uf').size().mean()
print(media_completa)
# Out:
# 22341.296296296296

# %%
# Convertendo KM para tipo númerico, para fazer a média
df['km'] = pd.to_numeric(df['km'], errors='coerce') # coerce é para que se a conversão não for bem sucedida, ele retornarar NaN
df_validos = df[df['km'].notnull()]

# %%
# Média por estado com dados válidos
media_filtrada = df_validos.groupby('uf').size().mean()

# %%
# Cálculando a variancia, para saber se a tabela está usável depois das dúvidas
variancia = media_completa - media_filtrada
print(f"Variação entre as médias: {variancia:.2f}")
# Out:
# Variação entre as médias: 9045.89

# %%
# Além da variação extremamente alta, há muitos registros em um único id
df['id'].value_counts().head(10)
# Out:
# id
# 661121    1540
# 651553     960
# 594793     960
# 660799     945
# 615922     920
# 614949     864
# 651899     792
# 579689     792
# 589865     650
# 622294     575
# Name: count, dtype: int64
